# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ### 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異

# %%
'''
Your Code
'''
'''
ANS: 使用[r.text] 讀出來的資料為字串格式
        [json.loads(r.text)] 會將字串轉換成json的格式
'''
import requests

r = requests.get('https://api.github.com/events')
r.text
# Out:
# esh/events{/privacy}","received_events_url":"https://api.github.com/users/VuppalaMahesh/received_events","type":"User","site_admin":false},"html_url":"https://github.com/VuppalaMahesh/AIM-HEALTH","description":"Manilla Project, This project built in by using HTML,CSS & Vanilla Javascript.","fork":false,"url":"https://api.github.com/repos/VuppalaMahesh/AIM-HEALTH","forks_url":"https://api.github.com/repos/VuppalaMahesh/AIM-HEALTH/forks","keys_url":"https://api.github.com/repos/VuppalaMahesh/AIM-HEALTH/keys{/key_id}","collaborators_url":"https://api.github.com/repos/VuppalaMahesh/AIM-HEALTH/collaborators{/collaborator}","teams_url":"https://api.github.com/repos/VuppalaMahesh/AIM-HEALTH/teams","hooks_url":"https://api.github.com/repos/VuppalaMahesh/AIM-HEALTH/hooks","issue_events_url":"https://api.github.com/repos/VuppalaMahesh/AIM-HEALTH/issues/events{/number}","events_url":"https://api.github.com/repos/VuppalaMahesh/AIM-HEALTH/events","assignees_url":"https://api.github.com/repos/VuppalaMahesh/AIM-HEALTH/assignees{/user}","branches_url":"https://api.github.com/repos/VuppalaMahesh/AIM-HEALTH/branches{/branch}","tags_url":"https://api.github.com/repos/VuppalaMahesh/AIM-HEALTH/tags","blobs_url":"https://api.github.com/repos/VuppalaMahesh/AIM-HEALTH/git/blobs{/sha}","git_tags_url":"https://api.github.com/repos/VuppalaMahesh/AIM-HEALTH/git/tags{/sha}","git_refs_url":"https://api.github.com/repos/VuppalaMahesh/AIM-HEALTH/git/refs{/sha}","trees_url":"https://api.github.com/repos/VuppalaMahesh/AIM-HEALTH/git/trees{/sha}","statuses_url":"https://api.github.com/repos/VuppalaMahesh/AIM-HEALTH/statuses/{sha}","languages_url":"https://api.github.com/repos/VuppalaMahesh/AIM-HEALTH/languages","stargazers_url":"https://api.github.com/repos/VuppalaMahesh/AIM-HEALTH/stargazers","contributors_url":"https://api.github.com/repos/VuppalaMahesh/AIM-HEALTH/contributors","subscribers_url":"https://api.github.com/repos/VuppalaMahesh/AIM-HEALTH/subscribers","subscription_url":"https://api.github.com/repos/VuppalaMahesh/AIM-HEALTH/subscription","commits_url":"https://api.github.com/repos/VuppalaMahesh/AIM-HEALTH/commits{/sha}","git_commits_url":"https://api.github.com/repos/VuppalaMahesh/AIM-HEALTH/git/commits{/sha}","comments_url":"https://api.github.com/repos/VuppalaMahesh/AIM-HEALTH/comments{/number}","issue_comment_url":"https://api.github.com/repos/VuppalaMahesh/AIM-HEALTH/issues/comments{/number}","contents_url":"https://api.github.com/repos/VuppalaMahesh/AIM-HEALTH/contents/{+path}","compare_url":"https://api.github.com/repos/VuppalaMahesh/AIM-HEALTH/compare/{base}...{head}","merges_url":"https://api.github.com/repos/VuppalaMahesh/AIM-HEALTH/merges","archive_url":"https://api.github.com/repos/VuppalaMahesh/AIM-HEALTH/{archive_format}{/ref}","downloads_url":"https://api.github.com/repos/VuppalaMahesh/AIM-HEALTH/downloads","issues_url":"https://api.github.com/repos/VuppalaMahesh/AIM-HEALTH/issues{/number}","pulls_url":"https://api.github.com/repos/VuppalaMahesh/AIM-HEALTH/pulls{/number}","milestones_url":"https://api.github.com/repos/VuppalaMahesh/AIM-HEALTH/milestones{/number}","notifications_url":"https://api.github.com/repos/VuppalaMahesh/AIM-HEALTH/notifications{?since,all,participating}","labels_url":"https://api.github.com/repos/VuppalaMahesh/AIM-HEALTH/labels{/name}","releases_url":"https://api.github.com/repos/VuppalaMahesh/AIM-HEALTH/releases{/id}","deployments_url":"https://api.github.com/repos/VuppalaMahesh/AIM-HEALTH/deployments","created_at":"2020-02-27T14:22:29Z","updated_at":"2020-02-27T14:33:14Z","pushed_at":"2020-02-27T14:33:05Z","git_url":"git://github.com/VuppalaMahesh/AIM-HEALTH.git","ssh_url":"git@github.com:VuppalaMahesh/AIM-HEALTH.git","clone_url":"https://github.com/VuppalaMahesh/AIM-HEALTH.git","svn_url":"https://github.com/VuppalaMahesh/AIM-HEALTH","homepage":"","size":0,"stargazers_count":0,"watchers_count":0,"language":"HTML","has_issues":true,"has_projects":true,"has_downloads":true,"has_wiki":true,"has_pages":false,"fork ...

# %%
import json
json.loads(r.text)
# Out:
# 'https://api.github.com/repos/VuppalaMahesh/AIM-HEALTH/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/VuppalaMahesh/AIM-HEALTH/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/VuppalaMahesh/AIM-HEALTH/merges',
#       'archive_url': 'https://api.github.com/repos/VuppalaMahesh/AIM-HEALTH/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/VuppalaMahesh/AIM-HEALTH/downloads',
#       'issues_url': 'https://api.github.com/repos/VuppalaMahesh/AIM-HEALTH/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/VuppalaMahesh/AIM-HEALTH/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/VuppalaMahesh/AIM-HEALTH/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/VuppalaMahesh/AIM-HEALTH/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/VuppalaMahesh/AIM-HEALTH/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/VuppalaMahesh/AIM-HEALTH/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/VuppalaMahesh/AIM-HEALTH/deployments',
#       'created_at': '2020-02-27T14:22:29Z',
#       'updated_at': '2020-02-27T14:33:14Z',
#       'pushed_at': '2020-02-27T14:33:05Z',
#       'git_url': 'git://github.com/VuppalaMahesh/AIM-HEALTH.git',
#       'ssh_url': 'git@github.com:VuppalaMahesh/AIM-HEALTH.git',
#       'clone_url': 'https://github.com/VuppalaMahesh/AIM-HEALTH.git',
#       'svn_url': 'https://github.com/VuppalaMahesh/AIM-HEALTH',
#       'homepage': '',
#       'size': 0,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'HTML',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': None,
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/VuppalaMahesh/AIM-HEALTH/pulls/1'},
#      'html': {'href': 'https://github.com/VuppalaMahesh/AIM-HEALTH/pull/1'},
#      'issue': {'href': 'https://api.github.com/repos/VuppalaMahesh/AIM-HEALTH/issues/1'},
#      'comments': {'href': 'https://api.github.com/repos/VuppalaMahesh/AIM-HEALTH/issues/1/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/VuppalaMahesh/AIM-HEALTH/pulls/1/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/VuppalaMahesh/AIM-HEALTH/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/VuppalaMahesh/AIM-HEALTH/pulls/1/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/VuppalaMahesh/AIM-HEALTH/statuses/ea86af615410f9eb6d01b9259f9dd0cc7e0d308d'}},
#     'author_association': 'NONE',
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 1,
#     'deletions': 1,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2020-02-27T14:33:50Z'},
#  {'id': '11626445099',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 51138685,
#    'login': 'poiana',
#    'display_login': 'poiana',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/poiana',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/51138685?'},
#   'repo': {'id': 190062497,
#    'name': 'falcosecurity/test-infra',
#    'url': 'https://api.github.com/repos/falcosecurity/test-infra'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/falcosecurity/test-infra/issues/93',
#     'repository_url': 'https://api.github.com/repos/falcosecurity/test-infra',
#     'labels_url': 'https://api.github.com/repos/falcosecurity/test-infra/issues/93/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/falcosecurity/test-infra/issues/93/comments',
#     'events_url': 'https://api.github.com/repos/falcosecurity/test-infra/issues/93/events',
#     'html_url': 'https://github.com/falcosecurity/test-infra/pull/93',
#     'id': 572113345,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzgwODc0NzU0',
#     'number': 93,
#     'title': 'new: build-service is now driverkit',
#     'user': {'login': 'fntlnz',
#      'id': 3083633,
#      'node_id': 'MDQ6VXNlcjMwODM2MzM=',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/3083633?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/fntlnz',
#      'html_url': 'https://github.com/fntlnz',
#      'followers_url': 'https://api.github.com/users/fntlnz/followers',
#      'following_url': 'https://api.github.com/users/fntlnz/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/fntlnz/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/fntlnz/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/fntlnz/subscriptions',
#      'organizations_url': 'https://api.github.com/users/fntlnz/orgs',
#      'repos_url': 'https://api.github.com/users/fntlnz/repos',
#      'events_url': 'https://api.github.com/users/fntlnz/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/fntlnz/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 1391337014,
#       'node_id': 'MDU6TGFiZWwxMzkxMzM3MDE0',
#       'url': 'https://api.github.com/repos/falcosecurity/test-infra/labels/approved',
#       'name': 'approved',
#       'color': 'ededed',
#       'default': False,
#       'description': None},
#      {'id': 1392923383,
#       'node_id': 'MDU6TGFiZWwxMzkyOTIzMzgz',
#       'url': 'https://api.github.com/repos/falcosecurity/test-infra/labels/dco-signoff:%20yes',
#       'name': 'dco-signoff: yes',
#       'color': 'b800d1',
#       'default': False,
#       'description': ''},
#      {'id': 1391336983,
#       'node_id': 'MDU6TGFiZWwxMzkxMzM2OTgz',
#       'url': 'https://api.github.com/repos/falcosecurity/test-infra/labels/lgtm',
#       'name': 'lgtm',
#       'color': 'c4f260',
#       'default': False,
#       'description': ''},
#      {'id': 1391336551,
#       'node_id': 'MDU6TGFiZWwxMzkxMzM2NTUx',
#       'url': 'https://api.github.com/repos/falcosecurity/test-infra/labels/size/M',
#       'name': 'size/M',
#       'color': 'b6c438',
#       'default': False,
#       'description': ''}],
#     'state': 'open',
#     'locked': False,
#     'assignee': {'login': 'leodido',
#      'id': 120051,
#      'node_id': 'MDQ6VXNlcjEyMDA1MQ==',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/120051?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/leodido',
#      'html_url': 'https://github.com/leodido',
#      'followers_url': 'https://api.github.com/users/leodido/followers',
#      'following_url': 'https://api.github.com/users/leodido/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/leodido/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/leodido/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/leodido/subscriptions',
#      'organizations_url': 'https://api.github.com/users/leodido/orgs',
#      'repos_url': 'https://api.github.com/users/leodido/repos',
#      'events_url': 'https://api.github.com/users/leodido/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/leodido/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'assignees': [{'login': 'leodido',
#       'id': 120051,
#       'node_id': 'MDQ6VXNlcjEyMDA1MQ==',
#       'avatar_url': 'https://avatars0.githubusercontent.com/u/120051?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/leodido',
#       'html_url': 'https://github.com/leodido',
#       'followers_url': 'https://api.github.com/users/leodido/followers',
#       'following_url': 'https://api.github.com/users/leodido/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/leodido/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/leodido/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/leodido/subscriptions',
#       'organizations_url': 'https://api.github.com/users/leodido/orgs',
#       'repos_url': 'https://api.github.com/users/leodido/repos',
#       'events_url': 'https://api.github.com/users/leodido/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/leodido/received_events',
#       'type': 'User',
#       'site_admin': False}],
#     'milestone': None,
#     'comments': 3,
#     'created_at': '2020-02-27T14:13:18Z',
#     'updated_at': '2020-02-27T14:33:48Z',
#     'closed_at': None,
#     'author_association': 'MEMBER',
#     'pull_request': {'url': 'https://api.github.com/repos/falcosecurity/test-infra/pulls/93',
#      'html_url': 'https://github.com/falcosecurity/test-infra/pull/93',
#      'diff_url': 'https://github.com/falcosecurity/test-infra/pull/93.diff',
#      'patch_url': 'https://github.com/falcosecurity/test-infra/pull/93.patch'},
#     'body': 'Co-Authored-By: Leonardo Di Donato <leodidonato@gmail.com>\r\nSigned-off-by: Lorenzo Fontana <lo@linux.com>'},
#    'comment': {'url': 'https://api.github.com/repos/falcosecurity/test-infra/issues/comments/592003633',
#     'html_url': 'https://github.com/falcosecurity/test-infra/pull/93#issuecomment-592003633',
#     'issue_url': 'https://api.github.com/repos/falcosecurity/test-infra/issues/93',
#     'id': 592003633,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDU5MjAwMzYzMw==',
#     'user': {'login': 'poiana',
#      'id': 51138685,
#      'node_id': 'MDQ6VXNlcjUxMTM4Njg1',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/51138685?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/poiana',
#      'html_url': 'https://github.com/poiana',
#      'followers_url': 'https://api.github.com/users/poiana/followers',
#      'following_url': 'https://api.github.com/users/poiana/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/poiana/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/poiana/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/poiana/subscriptions',
#      'organizations_url': 'https://api.github.com/users/poiana/orgs',
#      'repos_url': 'https://api.github.com/users/poiana/repos',
#      'events_url': 'https://api.github.com/users/poiana/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/poiana/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2020-02-27T14:33:42Z',
#     'updated_at': '2020-02-27T14:33:42Z',
#     'author_association': 'NONE',
#     'body': 'LGTM label has been added.  <details>Git tree hash: f888eadb3a9d00c7461665f28f50d3c106d9fe2f</details>'}},
#   'public': True,
#   'created_at': '2020-02-27T14:33:48Z',
#   'org': {'id': 42391047,
#    'login': 'falcosecurity',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/falcosecurity',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/42391047?'}},
#  {'id': '11626445232',
#   'type': 'WatchEvent',
#   'actor': {'id': 9432070,
#    'login': 'kreo',
#    'display_login': 'kreo',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kreo',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/9432070?'},
#   'repo': {'id': 69240232,
#    'name': 'lunelson/sass-calc',
#    'url': 'https://api.github.com/repos/lunelson/sass-calc'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2020-02-27T14:33:49Z'},
#  {'id': '11626445219',
#   'type': 'PushEvent',
#   'actor': {'id': 2098230,
#    'login': 'richelbilderbeek',
#    'display_login': 'richelbilderbeek',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/richelbilderbeek',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2098230?'},
#   'repo': {'id': 125844437,
#    'name': 'richelbilderbeek/pirouette',
#    'url': 'https://api.github.com/repos/richelbilderbeek/pirouette'},
#   'payload': {'push_id': 4690506414,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/richel',
#    'head': '44e727cd26b0fad45684f9cca53d2fd2d3b09fe2',
#    'before': 'ee032967a81b85f277c4ffa0a33235b4a9d4d2a9',
#    'commits': [{'sha': '44e727cd26b0fad45684f9cca53d2fd2d3b09fe2',
#      'author': {'email': 'richel@richelbilderbeek.nl',
#       'name': 'richelbilderbeek'},
#      'message': 'Thanks @lintr-bot',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/richelbilderbeek/pirouette/commits/44e727cd26b0fad45684f9cca53d2fd2d3b09fe2'}]},
#   'public': True,
#   'created_at': '2020-02-27T14:33:49Z'},
#  {'id': '11626445214',
#   'type': 'ForkEvent',
#   'actor': {'id': 37404702,
#    'login': 'Rushikesh1999',
#    'display_login': 'Rushikesh1999',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Rushikesh1999',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/37404702?'},
#   'repo': {'id': 210821363,
#    'name': 'Rodrob-93/Hospital-Finder',
#    'url': 'https://api.github.com/repos/Rodrob-93/Hospital-Finder'},
#   'payload': {'forkee': {'id': 243541256,
#     'node_id': 'MDEwOlJlcG9zaXRvcnkyNDM1NDEyNTY=',
#     'name': 'Hospital-Finder',
#     'full_name': 'Rushikesh1999/Hospital-Finder',
#     'private': False,
#     'owner': {'login': 'Rushikesh1999',
#      'id': 37404702,
#      'node_id': 'MDQ6VXNlcjM3NDA0NzAy',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/37404702?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Rushikesh1999',
#      'html_url': 'https://github.com/Rushikesh1999',
#      'followers_url': 'https://api.github.com/users/Rushikesh1999/followers',
#      'following_url': 'https://api.github.com/users/Rushikesh1999/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Rushikesh1999/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Rushikesh1999/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Rushikesh1999/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Rushikesh1999/orgs',
#      'repos_url': 'https://api.github.com/users/Rushikesh1999/repos',
#      'events_url': 'https://api.github.com/users/Rushikesh1999/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Rushikesh1999/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/Rushikesh1999/Hospital-Finder',
#     'description': None,
#     'fork': True,
#     'url': 'https://api.github.com/repos/Rushikesh1999/Hospital-Finder',
#     'forks_url': 'https://api.github.com/repos/Rushikesh1999/Hospital-Finder/forks',
#     'keys_url': 'https://api.github.com/repos/Rushikesh1999/Hospital-Finder/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/Rushikesh1999/Hospital-Finder/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/Rushikesh1999/Hospital-Finder/teams',
#     'hooks_url': 'https://api.github.com/repos/Rushikesh1999/Hospital-Finder/hooks',
#     'issue_events_url': 'https://api.github.com/repos/Rushikesh1999/Hospital-Finder/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/Rushikesh1999/Hospital-Finder/events',
#     'assignees_url': 'https://api.github.com/repos/Rushikesh1999/Hospital-Finder/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/Rushikesh1999/Hospital-Finder/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/Rushikesh1999/Hospital-Finder/tags',
#     'blobs_url': 'https://api.github.com/repos/Rushikesh1999/Hospital-Finder/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/Rushikesh1999/Hospital-Finder/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/Rushikesh1999/Hospital-Finder/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/Rushikesh1999/Hospital-Finder/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/Rushikesh1999/Hospital-Finder/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/Rushikesh1999/Hospital-Finder/languages',
#     'stargazers_url': 'https://api.github.com/repos/Rushikesh1999/Hospital-Finder/stargazers',
#     'contributors_url': 'https://api.github.com/repos/Rushikesh1999/Hospital-Finder/contributors',
#     'subscribers_url': 'https://api.github.com/repos/Rushikesh1999/Hospital-Finder/subscribers',
#     'subscription_url': 'https://api.github.com/repos/Rushikesh1999/Hospital-Finder/subscription',
#     'commits_url': 'https://api.github.com/repos/Rushikesh1999/Hospital-Finder/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/Rushikesh1999/Hospital-Finder/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/Rushikesh1999/Hospital-Finder/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/Rushikesh1999/Hospital-Finder/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/Rushikesh1999/Hospital-Finder/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/Rushikesh1999/Hospital-Finder/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/Rushikesh1999/Hospital-Finder/merges',
#     'archive_url': 'https://api.github.com/repos/Rushikesh1999/Hospital-Finder/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/Rushikesh1999/Hospital-Finder/downloads',
#     'issues_url': 'https://api.github.com/repos/Rushikesh1999/Hospital-Finder/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/Rushikesh1999/Hospital-Finder/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/Rushikesh1999/Hospital-Finder/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/Rushikesh1999/Hospital-Finder/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/Rushikesh1999/Hospital-Finder/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/Rushikesh1999/Hospital-Finder/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/Rushikesh1999/Hospital-Finder/deployments',
#     'created_at': '2020-02-27T14:33:46Z',
#     'updated_at': '2020-02-27T13:49:49Z',
#     'pushed_at': '2020-02-27T13:49:45Z',
#     'git_url': 'git://github.com/Rushikesh1999/Hospital-Finder.git',
#     'ssh_url': 'git@github.com:Rushikesh1999/Hospital-Finder.git',
#     'clone_url': 'https://github.com/Rushikesh1999/Hospital-Finder.git',
#     'svn_url': 'https://github.com/Rushikesh1999/Hospital-Finder',
#     'homepage': None,
#     'size': 8714,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': None,
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'master',
#     'public': True}},
#   'public': True,
#   'created_at': '2020-02-27T14:33:49Z'},
#  {'id': '11626445206',
#   'type': 'PushEvent',
#   'actor': {'id': 55650803,
#    'login': 'Bandal33',
#    'display_login': 'Bandal33',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Bandal33',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/55650803?'},
#   'repo': {'id': 243538916,
#    'name': 'Bandal33/bandal33.github.io',
#    'url': 'https://api.github.com/repos/Bandal33/bandal33.github.io'},
#   'payload': {'push_id': 4690506122,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '89b6f07823ce6bf36c6bbfa62f4e2662a483b656',
#    'before': '58deeff4189e10f005b4d1685913b39ec7d97d31',
#    'commits': [{'sha': '89b6f07823ce6bf36c6bbfa62f4e2662a483b656',
#      'author': {'email': '55650803+Bandal33@users.noreply.github.com',
#       'name': 'Bandal33'},
#      'message': 'Rename Index.html to index.html',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Bandal33/bandal33.github.io/commits/89b6f07823ce6bf36c6bbfa62f4e2662a483b656'}]},
#   'public': True,
#   'created_at': '2020-02-27T14:33:49Z'}]

# %% [markdown]
# ### 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#
# * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
'''
Your Code
https://cat-fact.herokuapp.com/facts
'''
r = requests.get('https://cat-fact.herokuapp.com/facts')
json.loads(r.text)
# Out:
# ', 'last': 'Koval'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59669484bf604b00205c20e3',
#    'text': 'The fear of cats is called "Ailurophobia"',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60b896acf530020f3586d',
#    'text': 'Cat owners are 25% likely to pick George Harrison as their favorite Beatle.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60b936acf530020f3586f',
#    'text': 'Only 11.5% of people consider themselves "cat people".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60b996acf530020f35870',
#    'text': '"Cat people" are 11% more likely to be introverted than others.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59b15b18d6eb960020d6767a',
#    'text': 'The place where Julius Caesar was murdered is now a cat sanctuary.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59ceab6d5c87bf0020b94e0a',
#    'text': 'The Bombay cat breed was developed to resemble a miniature panther.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59d297abc6671e0020957eb8',
#    'text': 'Cats use their whiskers to judge whether they’ll fit through a space.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038fba8e3dbc001f719794',
#    'text': 'Among domestic cats, males are more likely to fight than females.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a12460add20f9001fb45060',
#    'text': 'The softest part of a cat is most definitely its cheek area.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a36eb68ae877e0021ed79f3',
#    'text': "When a cat yawns, it's mouth opens so wide that you can count every tooth.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab252c99ee00219e11c3',
#    'text': 'Cats can move their ears 180 degrees.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d78136ef087002174c292',
#    'text': 'Like humans, cats tend to favor one paw over another.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d79496ef087002174c294',
#    'text': 'Approximately 40,000 people are bitten by cats in the U.S. annually.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4911340508220014ccfe92',
#    'text': 'Kittens start to dream when they’re about a week old.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c609ae8e54902001453303b',
#    'text': 'Approximately 40% of cats have a dominant paw. The rest are ambidextrous.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c409c2d7a200140f67ec',
#    'text': 'Cats can have three litters a year, or approximately 12 kittens.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c35531e8e0b8d00148d45e8',
#    'text': "If you grow your own catnip, here's how to prepare it for kitty's enjoyment: Cut several stalks of the plant from the base. Hang them upside down in a dark and dry room for several weeks. Then cut the catnip into small pieces, rub some on your cat's favorite toys or scratching post, and let the games begin!",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3bba466bd7ea00141eff4f',
#    'text': 'Approximately 80% of orange tabbies are male.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3bbab76bd7ea00141eff50',
#    'text': 'If you need to trim a cat\'s nails, choose a moment when he is relaxed. Massage his paws gently before clipping. Make sure you\'re using a pair of clippers specifically for cat\'s nails, not human nail clippers. Avoid cutting the nail too close to the "quick," the pink part of a cat\'s nail, which is full of blood vessels and nerves.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c471b30a99c3f00140fe4c5',
#    'text': 'The collective noun for kittens is a "kindle".',
#    'type': 'cat',
#    'user': {'_id': '5c471b15a99c3f00140fe4c4',
#     'name': {'first': 'Beth', 'last': 'Rothwell'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c609945e549020014533037',
#    'text': 'Do you ever wake up in the middle of the night and find your cat sleeping on your head? Cat behavioral experts believe that cats are drawn to the warmth and the familiar scent of the owner. Resting on your head also keeps kitty safe from your arms and legs if you toss and turn through the night.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c7408a14dd87d001490f02b',
#    'text': "The cheetah is the only cat that doesn't have retractable claws.",
#    'type': 'cat',
#    'user': {'_id': '5c72e94751021f001415f012',
#     'name': {'first': 'Tests', 'last': 'HiQ'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c75f56272681400147b988a',
#    'text': 'There are only two escalators in the state of Wyoming.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c84248f731a60001540a193',
#    'text': 'When a cat lifts its butt in the air when scratched, it is a sign that your feline is giving your pats an A+. However, if you have a female kitty who hasn\'t been spayed, "elevator butt" could be a sign that she\'s ready to mate. The proper name for this stance is lordosis, and cats adopt it when they\'re in heat.',
#    'type': 'cat',
#    'user': {'_id': '5c7da4bd70008708fb17c88f',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c87d03dec1e5c0aa37e0a6b',
#    'type': 'cat',
#    'text': 'On October 24, 1963, a tuxedo cat named Félicette entered outer space aboard a French Véronique AG1 rocket and made feline history. Félicette returned from the 15-minute trip in once piece and earned the praise of French scientists, who said she made "a valuable contribution to research.".',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5cd42b77cfdf230015bd7a45',
#    'text': 'Cats can sense distress from a human being.',
#    'type': 'cat',
#    'user': {'_id': '5cd42b40cfdf230015bd7a44',
#     'name': {'first': 'Chloe', 'last': 'Simmons'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5cd86b0e1dc6d50015ec2f08',
#    'text': 'Norwegian Forest Cats are usually very people friendly.',
#    'type': 'cat',
#    'user': {'_id': '5cd86adb1dc6d50015ec2f07',
#     'name': {'first': 'Shay', 'last': 'Zhang'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b1d40f1c57001592f12c',
#    'type': 'cat',
#    'text': "During the heat of the summer, set out an extra bowl of water and place ice cubes in it to keep it cold and refreshing. Cats love to lie on cool surfaces when it's hot—if you don't have an tile in your home, consider buying a few ceramic tiles from a home improvement store for your cat to rest on.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b2510f1c57001592f12e',
#    'type': 'cat',
#    'text': 'Courgars are the largest wild cats that can purr.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b5b50f1c57001592f131',
#    'type': 'cat',
#    'text': 'Andy Warhol amassed quite the collection of feline friends during his lifetime, beginning with a Siamese cat named Hester that was given to him by actress Gloria Swanson. By breeding Hester with a cat named Sam, Warhol ended up with multiple litters of kittens, at one point housing 25 cats in his Upper East Side townhouse in NYC.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b6090f1c57001592f132',
#    'type': 'cat',
#    'text': 'While two kittens might sound like double trouble, adopting two at a time can actually make your job easier. Two cans can keep each other company, reducing their need for socialization, and they will expend energy by playing together. Kittens in the same litter often form tight sibling bonds.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38bb910f1c57001592f14e',
#    'type': 'cat',
#    'text': 'Dr. Seuss wrote The Cat in the Hat using only 236 words.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d9d4ae168a764001553b388',
#    'type': 'cat',
#    'text': 'Cats conserve energy by sleeping for an average of 13 to 14 hours a day.',
#    'user': {'_id': '5d9d4a4468a764001553b387',
#     'name': {'first': 'Erick', 'last': 'Vazquez'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5e10d7841c78ab0015bc5b15',
#    'type': 'cat',
#    'text': 'Some cats do not eat fish.',
#    'user': {'_id': '5e10d6e51c78ab0015bc5b14',
#     'name': {'first': 'Max', 'last': 'Bilohatnyuk'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e19da391fd6150015fa7356',
#    'type': 'cat',
#    'text': '"Cats can hear the ultrasonic noises that rodents and dolphins make to communicate.".',
#    'user': {'_id': '5e19d99e1fd6150015fa7353',
#     'name': {'first': 'Crystal Gale', 'last': 'Scott'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e1efba858449a0015ce4783',
#    'type': 'cat',
#    'text': '"A house cat is faster than Usain Bolt.".',
#    'user': {'_id': '5e1efb5958449a0015ce4781',
#     'name': {'first': 'oyaji', 'last': '55'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e239999dc76630015d4c5e2',
#    'type': 'cat',
#    'text': 'Cats see only on blue and yellow.',
#    'user': {'_id': '5e239963dc76630015d4c5e1',
#     'name': {'first': 'Eduardo', 'last': 'P. Gomez'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e27232ec71d0900152d8518',
#    'type': 'cat',
#    'text': 'Cats are dumb.',
#    'user': {'_id': '5e272323c71d0900152d8517',
#     'name': {'first': 'Andrew', 'last': 'Steele'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e2f9f1ade397c00152dd552',
#    'type': 'cat',
#    'text': 'Cat.',
#    'user': {'_id': '5e2f9f0ede397c00152dd551',
#     'name': {'first': 'bah', 'last': 'godam99'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e2f9f23de397c00152dd553',
#    'type': 'cat',
#    'text': 'Sleep.',
#    'user': {'_id': '5e2f9f0ede397c00152dd551',
#     'name': {'first': 'bah', 'last': 'godam99'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e3382ccd7ac48001509e153',
#    'type': 'cat',
#    'text': 'Cat is an animal.',
#    'user': {'_id': '5e3381f3d7ac48001509e151',
#     'name': {'first': 'Dicka', 'last': 'Ismaji'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e344e7acd8efb0015ae3055',
#    'type': 'cat',
#    'text': 'Cat live, on average, for about 7-8 years.',
#    'user': {'_id': '5e344e3ccd8efb0015ae3054',
#     'name': {'first': 'RYAN', 'last': 'STULTZ'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e3534d8cd8efb0015ae305c',
#    'type': 'cat',
#    'text': 'Hi.',
#    'user': {'_id': '5e3534b4cd8efb0015ae305b',
#     'name': {'first': 'Durgarao', 'last': 'R'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e35436d11559000151bf453',
#    'type': 'cat',
#    'text': '123.',
#    'user': {'_id': '5e3534b4cd8efb0015ae305b',
#     'name': {'first': 'Durgarao', 'last': 'R'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e355bf411559000151bf454',
#    'type': 'cat',
#    'text': 'Fgf.',
#    'user': {'_id': '5e3534b4cd8efb0015ae305b',
#     'name': {'first': 'Durgarao', 'last': 'R'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e380ea32035630015618254',
#    'type': 'cat',
#    'text': 'Asd.',
#    'user': {'_id': '5e380e9b2035630015618253',
#     'name': {'first': 'dm', 'last': 'max'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e56fdf375991a0015429ffc',
#    'type': 'cat',
#    'text': 'Bbb.',
#    'user': {'_id': '5e56fddd75991a0015429ffb',
#     'name': {'first': 'Cristian', 'last': 'Salcedo'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38baf20f1c57001592f14b',
#    'type': 'cat',
#    'text': "The stationmaster of the Kishi rail station in western Japan until 2015 was a cat named Tama. The calico cat wore a stationmaster's cap and greeted visitors by the ticket gate. After her death, Tama was elevated to the status of a goddess in a Shinto-style funeral.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bb7a0f1c57001592f14d',
#    'type': 'cat',
#    'text': 'In Norse mythology, the goddess Freya travels in a chariot pulled by two cats—specifically Norwegian Forest Cats.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bbb20f1c57001592f14f',
#    'type': 'cat',
#    'text': 'American Curl kittens are born with straight ears, but the ears begin to curl back after just a few days.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc0c0f1c57001592f150',
#    'type': 'cat',
#    'text': "If your cat licks from the toilet, bathtub, or sink, she may be telling you something about the water bowl. Make sure it's clean, replace the water regularly to keep it from getting stale or developing a film on top, and if necessary, get a new bowl. Some cats prefer glass bowls to plastic.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc630f1c57001592f151',
#    'type': 'cat',
#    'text': "Georgia O'Keeffe was a celebrated painter, a figurehead of American modernism, a fashion icon, and... a cat owner! O'Keeffe kept a number of animals at her home in New Mexico, including her pet Siamese cat, who appears alongside O'Keeffe in a portrait shot by photographer John Candelario.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc970f1c57001592f152',
#    'type': 'cat',
#    'text': 'The pink substance inside a cat\'s nail is called the "quick" or the "dermis". When trimming your cat\'s nails, be sure to only cut the upper white part of the nail, not the quick.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bcc00f1c57001592f153',
#    'type': 'cat',
#    'text': 'The irresistable and cuddly Ragamuffin is the result of crossbreeding Ragdoll cats with Persians, Himalayans, and other larger longhaired breeds.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bd180f1c57001592f154',
#    'type': 'cat',
#    'text': 'Cats are among only a few animals that walk by moving their two right legs one after another and then their two left legs, rather than moving diagonal limbs simultaneously. Giraffes and camels also have this quality.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bd750f1c57001592f155',
#    'type': 'cat',
#    'text': "Legend holds that a goddess rewarded a temple cat's piety by turning the cat's eyes blue and his coat golden, thus creating the first Birman cat.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bdab0f1c57001592f156',
#    'type': 'cat',
#    'text': "While some cats love being brushed, others don't take to it naturally. Try to groom your cat in the same spot at the same time of day to create a sense of routine.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38be370f1c57001592f158',
#    'type': 'cat',
#    'text': 'Kittens typically begin to engage in playful behavior at around four weeks of age.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bb440f1c57001592f14c',
#    'type': 'cat',
#    'text': "It's important for cats to have regular ear exams—this is something you can do at home! Gently fold back the ears and look into the ear canal. The inner ear should be pale pink with little to no earwax. If you notice redness, swelling, discharge, or a lot of earwax, it's time to see a veterinarian.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e353507cd8efb0015ae305d',
#    'type': 'cat',
#    'text': 'Test.',
#    'user': {'_id': '5e3534b4cd8efb0015ae305b',
#     'name': {'first': 'Durgarao', 'last': 'R'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e4c4e10a38ae60015b04a7e',
#    'type': 'cat',
#    'text': "Cats think humans have night vision too, so when we step on their tail in the middle of the night, they think it's on purpose.",
#    'user': {'_id': '5e4c4dc5a38ae60015b04a7d',
#     'name': {'first': 'Nathaniel J', 'last': 'McDermott'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e546a054e83e80015a0e320',
#    'type': 'cat',
#    'text': "Contrary to popular belief, some cats actually don't mind water. The hairless Sphynx cat enjoys it, especially if it is warm.",
#    'user': {'_id': '5e54675a4e83e80015a0e313',
#     'name': {'first': "L'hibou", 'last': 'Ambigu'}},
#    'upvotes': 0,
#    'userUpvoted': None}]}

# %%
r = requests.get('http://odata.wra.gov.tw/v4/RealtimeWaterLevel')

json.loads(r.text)
# Out:
# {'@odata.context': 'http://odata.wra.gov.tw/v4/$metadata#RealtimeWaterLevel',
#  '@odata.count': 100,
#  'value': [{'StationIdentifier': '2200H029',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 145.15},
#   {'StationIdentifier': '1730H070',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 226.25},
#   {'StationIdentifier': '1580H021',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 1.28},
#   {'StationIdentifier': '1580H017',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 25.73},
#   {'StationIdentifier': '2560H019',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 4.48},
#   {'StationIdentifier': '1580H001',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 224.21},
#   {'StationIdentifier': '1730H075',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 92.83},
#   {'StationIdentifier': '2420H036',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 164.37},
#   {'StationIdentifier': '2500H003',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 32.2},
#   {'StationIdentifier': '1730H066',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 138.73},
#   {'StationIdentifier': '1730H077',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 740.49},
#   {'StationIdentifier': '1550H014',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 26.75},
#   {'StationIdentifier': '1670H004',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 2.98},
#   {'StationIdentifier': '2420H019',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 109.97},
#   {'StationIdentifier': '1650H012',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 0.7},
#   {'StationIdentifier': '1730H061',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 266.23},
#   {'StationIdentifier': '1730H072',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 248.86},
#   {'StationIdentifier': '1540H039',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 38.99},
#   {'StationIdentifier': '1660H012',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 0.14},
#   {'StationIdentifier': '2370H025',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 261.61},
#   {'StationIdentifier': '1650H009',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 0.1},
#   {'StationIdentifier': '1730H057',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 43.48},
#   {'StationIdentifier': '1730H068',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 10.14},
#   {'StationIdentifier': '1540H037',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 32.01},
#   {'StationIdentifier': '1650H015',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 0.05},
#   {'StationIdentifier': '2370H018',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 124.1},
#   {'StationIdentifier': '1630H036',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 65.83},
#   {'StationIdentifier': '1660H009',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 4.85},
#   {'StationIdentifier': '1730H043',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 23.04},
#   {'StationIdentifier': '2420H043',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 79.32},
#   {'StationIdentifier': '1540H033',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 23.4},
#   {'StationIdentifier': '1650H010',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 0.19},
#   {'StationIdentifier': '1630H030',
#    'RecordTime': 'Dec 11, 2019 2:20:00 PM',
#    'WaterLevel': 1.57},
#   {'StationIdentifier': '1630H032',
#    'RecordTime': 'Dec 11, 2019 2:20:00 PM',
#    'WaterLevel': 0.13},
#   {'StationIdentifier': '1650H013',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 5.62},
#   {'StationIdentifier': '1680H005',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 0.11},
#   {'StationIdentifier': '2200H026',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 106.73},
#   {'StationIdentifier': '1350H031',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': -0.15},
#   {'StationIdentifier': '1630H040',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 1.76},
#   {'StationIdentifier': '1630H018',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 10.01},
#   {'StationIdentifier': '1630H027',
#    'RecordTime': 'Dec 11, 2019 2:20:00 PM',
#    'WaterLevel': 26.14},
#   {'StationIdentifier': '1540H032',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 20.45},
#   {'StationIdentifier': '1550H012',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 0.54},
#   {'StationIdentifier': '1630H023',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 0.03},
#   {'StationIdentifier': '1350H029',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 175.97},
#   {'StationIdentifier': '1630H034',
#    'RecordTime': 'Dec 11, 2019 2:20:00 PM',
#    'WaterLevel': 278.47},
#   {'StationIdentifier': '1590H016',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 11.27},
#   {'StationIdentifier': '1630H024',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 69.07},
#   {'StationIdentifier': '1540H029',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 13.13},
#   {'StationIdentifier': '1540H030',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 27.2},
#   {'StationIdentifier': '1630H005',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 39.76},
#   {'StationIdentifier': '1350H027',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 145.89},
#   {'StationIdentifier': '1510H082',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 752.39},
#   {'StationIdentifier': '1580H022',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 0.16},
#   {'StationIdentifier': '1430H054',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 48.29},
#   {'StationIdentifier': '1510H084',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 145.06},
#   {'StationIdentifier': '1540H009',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 0.59},
#   {'StationIdentifier': '1590H013',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 20.76},
#   {'StationIdentifier': '1510H080',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 1068.94},
#   {'StationIdentifier': '1510H058',
#    'RecordTime': 'Dec 11, 2019 9:50:00 AM',
#    'WaterLevel': 12.13},
#   {'StationIdentifier': '1430H037',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 380.46},
#   {'StationIdentifier': '1430H051',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 95.66},
#   {'StationIdentifier': '1350H024',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 259.67},
#   {'StationIdentifier': '1520H008',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 78.22},
#   {'StationIdentifier': '1580H018',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 21.23},
#   {'StationIdentifier': '1510H079',
#    'RecordTime': 'Dec 11, 2019 9:50:00 AM',
#    'WaterLevel': 187.7},
#   {'StationIdentifier': '1510H049',
#    'RecordTime': 'Dec 11, 2019 9:50:00 AM',
#    'WaterLevel': 470.82},
#   {'StationIdentifier': '1430H029',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 50.6},
#   {'StationIdentifier': '1430H047',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 72.35},
#   {'StationIdentifier': '1350H020',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 220.79},
#   {'StationIdentifier': '1510H086',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 317.97},
#   {'StationIdentifier': '1580H008',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 19.39},
#   {'StationIdentifier': '1510H071',
#    'RecordTime': 'Dec 11, 2019 9:50:00 AM',
#    'WaterLevel': 20.5},
#   {'StationIdentifier': '1430H056',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 79.83},
#   {'StationIdentifier': '1420H057',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 639.41},
#   {'StationIdentifier': '1420H058',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 440.47},
#   {'StationIdentifier': '1350H016',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 97.9},
#   {'StationIdentifier': '1550H017',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 15.74},
#   {'StationIdentifier': '1510H075',
#    'RecordTime': 'Dec 11, 2019 9:50:00 AM',
#    'WaterLevel': 346.5},
#   {'StationIdentifier': '1430H045',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 91.76},
#   {'StationIdentifier': '1430H058',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 83.01},
#   {'StationIdentifier': '1400H015',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 622.43},
#   {'StationIdentifier': '1420H055',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 318.68},
#   {'StationIdentifier': '1340H015',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 50.08},
#   {'StationIdentifier': '1420H054',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 704.2},
#   {'StationIdentifier': '1350H018',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 282.05},
#   {'StationIdentifier': '1430H040',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 19.29},
#   {'StationIdentifier': '1340H014',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 0.37},
#   {'StationIdentifier': '1400H009',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 191.55},
#   {'StationIdentifier': '1140H106',
#    'RecordTime': 'Dec 11, 2019 2:55:00 PM',
#    'WaterLevel': 49.11},
#   {'StationIdentifier': '2370H017',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 58.49},
#   {'StationIdentifier': '1420H049',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 54.19},
#   {'StationIdentifier': '1350H001',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 169.81},
#   {'StationIdentifier': '1300H022',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': -1.01},
#   {'StationIdentifier': '1340H011',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 7.38},
#   {'StationIdentifier': '1140H108',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 12.12},
#   {'StationIdentifier': '1140H099',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 263.49},
#   {'StationIdentifier': '1850H005',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 22.09},
#   {'StationIdentifier': '1400H019',
#    'RecordTime': 'Dec 11, 2019 2:40:00 PM',
#    'WaterLevel': 310.14},
#   {'StationIdentifier': '1290H002',
#    'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'WaterLevel': 41}],
#  '@odata.nextLink': 'http://odata.wra.gov.tw/v4/RealtimeWaterLevel?$skip=100&$top=100'}
